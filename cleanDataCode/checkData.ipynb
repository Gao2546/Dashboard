# %%
import pandas 

df = pandas.read_csv("information/june1_2562_contract_clean.csv")
df
# Out:
#                                                proj_name  \
# 0      ซื้อจัดซื้อลูกประคบ สมุนไพรแช่เท้า และสมุนไพรท...
# 1      ซื้อวัสดุการศึกษา โครงการพัฒนาการสมวัย เด็กไทย...
# 2        จ้างจัดจ้างซ่อมยูนิตทันตกรรม โดยวิธีเฉพาะเจาะจง
# 3            ซื้อซื้อวัสดุคอมพิวเตอร์ โดยวิธีเฉพาะเจาะจง
# 4      จ้างจ้างซ่อมเครื่องปรับอากาศรถยนต์ โดยวิธีเฉพา...
# ...                                                  ...
# 96350  จ้างซ่อมรถยนต์ขนาด 24 ตัน หมายเลขทะเบียน 82-46...
# 96351  ซื้อจัดซื้อผลิตภัณฑ์คอนกรีต งาน คพจ.1 โดยวิธีเ...
# 96352  ซื้อจัดซื้อผลิตภัณฑ์คอนกรีต งาน คฟม โดยวิธีเฉพ...
# 96353  จ้างปรับปรุงฯย้ายแนว บ้านยางโทน(สมศักดิ์ โตรัก...
# 96354  จ้างปรับปรุงฯบ้านวังใหญ่ถึงสี่แยก ม.5 ต.ท่าเสา...
#
#                                    subdep_name  contrct_price  subdep_id  \
# 0          โรงพยาบาลส่งเสริมสุขภาพตำบลบางเมือง        5200.00       8384
# 1            โรงพยาบาลส่งเสริมสุขภาพตำบลแพรกษา       12000.00       8384
# ...

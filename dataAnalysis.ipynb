# %%
import pandas

df = pandas.read_csv('In_march_to_oct2562.csv', low_memory=False)

df.head(100)
# Out:
#     Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0      proj_no  \
# 0              0             0           0  62037491194
# 1              1             1           1  62037413920
# 2              2             2           2  62037526775
# 3              3             3           3  62037470394
# 4              4             4           4  62037367644
# ..           ...           ...         ...          ...
# 95            95            95          95  62037310145
# 96            96            96          96  62037294775
# 97            97            97          97  62037296953
# 98            98            98          98  62037326422
# 99            99            99          99  62037378358
#
#                                             proj_name  \
# 0   ซื้อจัดซื้อวัสดุประกอบกิจกรรมเพื่อใช้ในงาน โคร...
# 1          ซื้อวัสดุงานบ้านงานครัว โดยวิธีเฉพาะเจาะจง
# 2   จ้างทำสื่อเผยแพร่ประชาสัมพันธ์ โดยวิธีเฉพาะเจาะจง
# 3   ซื้อวัสดุคอมพิวเตอร์  จำนวน  5  รายการ โดยวิธี...
# ...

# %%
df[df['typ_name'] == 'จ้างก่อสร้าง']
# Out:
#          Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0      proj_no  \
# 281               281           281         281  62037437530
# 328               328           328         328  62037034266
# 480               480           480         480  62037123712
# 481               481           481         481  62037365824
# 556               556           556         556  62037532515
# ...               ...           ...         ...          ...
# 2494016        118316        118316      118316  62037489476
# 2494042        118342        118342      118342  62107087855
# 2494045        118345        118345      118345  62107045792
# 2494084        118384        118384      118384  62107263931
# 2494085        118385        118385      118385  62107272534
#
#                                                  proj_name  \
# 281                จ้างซ่อมแซมทาสีอาคาร โดยวิธีเฉพาะเจาะจง
# 328      จ้างจ้างเหมาซ่อมแซม ปรับปรุงห้องน้ำผู้พิการ ขอ...
# ...

# %%
import pandas

df = pandas.read_csv('In_march_to_oct2562.csv', low_memory=False)

df.head(100)
# Out:
#     Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0      proj_no  \
# 0              0             0           0  62037491194
# 1              1             1           1  62037413920
# 2              2             2           2  62037526775
# 3              3             3           3  62037470394
# 4              4             4           4  62037367644
# ..           ...           ...         ...          ...
# 95            95            95          95  62037310145
# 96            96            96          96  62037294775
# 97            97            97          97  62037296953
# 98            98            98          98  62037326422
# 99            99            99          99  62037378358
#
#                                             proj_name  \
# 0   ซื้อจัดซื้อวัสดุประกอบกิจกรรมเพื่อใช้ในงาน โคร...
# 1          ซื้อวัสดุงานบ้านงานครัว โดยวิธีเฉพาะเจาะจง
# 2   จ้างทำสื่อเผยแพร่ประชาสัมพันธ์ โดยวิธีเฉพาะเจาะจง
# 3   ซื้อวัสดุคอมพิวเตอร์  จำนวน  5  รายการ โดยวิธี...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2494110 entries, 0 to 2494109
# Data columns (total 18 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Unnamed: 0.2    int64
#  1   Unnamed: 0.1    int64
#  2   Unnamed: 0      int64
#  3   proj_no         int64
#  4   proj_name       object
#  5   subdep_name     object
#  6   proj_mny        float64
#  7   cost_build      float64
#  8   mthd_name       object
#  9   typ_name        object
#  10  win_tin         object
#  11  corp_name       object
#  12  contrct_price   float64
#  13  contrct_date    object
#  14  contrct_fhdate  object
#  15  LATITUDE        float64
#  16  LONGTITUDE      float64
#  17  month           object
# dtypes: float64(5), int64(4), object(9)
# memory usage: 342.5+ MB
